# %%
import copy

# %%
### 자주 쓰는 자료구조 ###

## 리스트
# 정렬 , 앞에게 우선 정렬
lst = sorted(lst, key = lambda x : (x[0], -x[1]))
lst.index("value") # 값 없으면 error 발생

## 문자열 
string.lower()
stirng.find(lst_str , start , end )
string.split()
string.split("#")

## 딕셔너리
# 벨류값을 리스트로 이용하기 , 키값을 리스트로 이용할려면 리스트를 str 로 전환해서 키로 쓰자
from collections import defaultdict
dic = defaultdict(list)
# 딕셔너리 관련 자주 쓰는 표현들
dic.keys()
dic.values()
if not dic['key']: print("처음 등록한 키")
    
## 세트 : 집합 연산에 자주 이용 , 중복제거 , 차집합 , 세트안에는 1차 리스트 까지만
set(lst)
set(lst_1) - set(lst_2)

## 전역변수 선언:
global item # 이용할 함수에서 global 선언
# 지역변수와 중첩안되게 조심하기(for문의 변수도 마찬가지)

# %%
### 자주 쓰이는 제어 구조 ###

## If 문

## For 문
# 제어 변수 index , 신경 쓰기
# 끝값 처리 중요
# 다중 For 문시 Flag 이용하거나 지역함수로 만들어서 Return으로 종료시킬것

## While 문

## Try Except 문
# 2차원배열 처리 용이 , 다만 바운더리 처리 잘못하면 꼬일수 있다

# %%
### 자주 쓰이는 알고리즘 ###

## 순열 / 조합 라이브러리 이용
from itertools import combinations
from itertools import permutations
permutations(lst,r)
combinations(lst,r)


## DFS , BFS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-39759a6daad6> in <module>
#       3 from itertools import combinations
#       4 from itertools import permutations
# ----> 5 permutations(lst,r)
#       6 combinations(lst,r)
#       7
#
# NameError: name 'lst' is not defined

# %%
a = [1,4,6, 1]
def b():
    a = 100
    print(a)
   
b()
# Out:
# 100

# %%
import re
new_id = "sdfsdfefsdf????<>"
new_id = re.sub('[+!@#$%^&*()=+[{]', '', new_id)
new_id = re.sub('[}:?,<>]', '', new_id)
new_id
# Out:
# 'sdfsdfefsdf'

# %%
new_id = "........2414...324sfdsf..."

for s in new_id:
    start = 0; index = 0
    if s == ".":
        index = new_id.index(s)
        start = index
        while(1):
            if new_id[index + 1] != ".":    break
            else:   index = index + 1

while(1):
    if not new_id.find('.'):
        index = new_id.find('.')
        if new_id[index + 1] == '.':
            del(new_id[index + 1])
    else: break



if new_id[0] == ".":    del(new_id[0])
if new_id[-1] == ".":   del(new_id[-1])
print(new_id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-d46e7d53ff9c> in <module>
#      14         index = new_id.find('.')
#      15         if new_id[index + 1] == '.':
# ---> 16             del(new_id[index + 1])
#      17     else: break
#      18
#
# TypeError: 'str' object doesn't support item deletion

# %%
new_id = "........2414...324sfdsf..."

while(1):
    if not new_id.find('.'):
        index = new_id.find('.')
        if new_id[index + 1] == '.':
            new_id = new_id[0:index + 1] + new_id[index + 2:-1 ]
        print(new_id)
    else: break
print(new_id)
# Out:
# .......2414...324sfdsf..
# ......2414...324sfdsf.
# .....2414...324sfdsf
# ....2414...324sfds
# ...2414...324sfd
# ..2414...324sf
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# .2414...324s
# ...
